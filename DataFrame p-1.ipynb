# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

np.random.seed(101)

# %%
df=pd.DataFrame(randn(5,5),index='A B C D E'.split(),columns='a b c d e'.split())
df
# Out:
#           a         b         c         d         e
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
df['a']
# Out:
# A    2.706850
# B   -0.319318
# C    0.528813
# D    0.955057
# E    0.302665
# Name: a, dtype: float64

# %%
df[['a','b']]
# Out:
#           a         b
# A  2.706850  0.628133
# B -0.319318 -0.848077
# C  0.528813 -0.589001
# D  0.955057  0.190794
# E  0.302665  1.693723

# %%
df['ab']=df['a']+df['b']

# %%
df
# Out:
#           a         b         c         d         e        ab
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
df['cde']=df['c']+df['d']+df['e']

# %%
df
# Out:
#           a         b         c         d         e        ab       cde
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983  2.062913
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395 -0.672081
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187 -1.503414
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851  5.268233
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388 -3.000046

# %%
df.drop('A',axis=0)
# Out:
#           a         b         c         d         e        ab       cde
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395 -0.672081
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187 -1.503414
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851  5.268233
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388 -3.000046

# %%
df.drop('cde',axis=1,inplace=True)

# %%
df
# Out:
#           a         b         c         d         e        ab
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
df.loc['C']
# Out:
# a     0.528813
# b    -0.589001
# c     0.188695
# d    -0.758872
# e    -0.933237
# ab   -0.060187
# Name: C, dtype: float64

# %%
df.iloc[1]
# Out:
# a    -0.319318
# b    -0.848077
# c     0.605965
# d    -2.018168
# e     0.740122
# ab   -1.167395
# Name: B, dtype: float64

# %%
df>0
# Out:
#        a      b      c      d      e     ab
# A   True   True   True   True   True   True
# B  False  False   True  False   True  False
# C   True  False   True  False  False  False
# D   True   True   True   True   True   True
# E   True   True  False  False  False   True

# %%
df[df['c']>0]
# Out:
#           a         b         c         d         e        ab
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851

# %%
df
# Out:
#           a         b         c         d         e        ab
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
df[df['B']>0&df['c']>0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7085d758338> in <module>
# ----> 1 df[df['B']>0&df['c']>0]
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#           a         b         c         d         e        ab
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
df.reset_index()
# Out:
#   index         a         b         c         d         e        ab
# 0     A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# 1     B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# 2     C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# 3     D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# 4     E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
name_create='AA BB CC DD EE'.split()

# %%
df['Create']=name_create

# %%
df
# Out:
#           a         b         c         d         e        ab Create
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983     AA
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395     BB
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187     CC
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851     DD
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388     EE

# %%
df.set_index('Create')
# Out:
#                a         b         c         d         e        ab
# Create
# AA      2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# BB     -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# CC      0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# DD      0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# EE      0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
df
# Out:
#           a         b         c         d         e        ab Create
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983     AA
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395     BB
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187     CC
# D  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851     DD
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388     EE

# %%
df.set_index('Create',inplace=True)

# %%
df
# Out:
#                a         b         c         d         e        ab
# Create
# AA      2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# BB     -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# CC      0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# DD      0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# EE      0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
df.reset_index()
# Out:
#   Create         a         b         c         d         e        ab
# 0     AA  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# 1     BB -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# 2     CC  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# 3     DD  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# 4     EE  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
name_number='A B C D E'.split()

# %%
df['Number']=name_number

# %%
df
# Out:
#                a         b         c         d         e        ab Number
# Create
# AA      2.706850  0.628133  0.907969  0.503826  0.651118  3.334983      A
# BB     -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395      B
# CC      0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187      C
# DD      0.955057  0.190794  1.978757  2.605967  0.683509  1.145851      D
# EE      0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388      E

# %%
df.set_index('Number')
# Out:
#                a         b         c         d         e        ab
# Number
# A       2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# B      -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# C       0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# D       0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# E       0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
